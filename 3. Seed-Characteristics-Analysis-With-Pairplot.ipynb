# %% [markdown]
# # Seed-Characteristics-Analysis-With-Pairplot

# %% [markdown]
# This code analyzes a dataset on seeds characteristics, including attributes like area, perimeter, compactness, and others. It loads the dataset, sets column names, and provides descriptive statistics. It visualizes the relationships between variables using pairplots. However, there seems to be a syntax error in the code. Here's a revised version:

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
df1 = pd.read_csv('seeds_dataset.csv',header=None)
df1.columns = ["area", "perimeter", "compactness", "length of kernel","width of kernel", "asymmetry coefficient", "length of kernel groove","U/K"]
df1.head()
# Out:
#     area  perimeter  compactness  length of kernel  width of kernel  \
# 0  15.26      14.84       0.8710             5.763            3.312
# 1  14.88      14.57       0.8811             5.554            3.333
# 2  14.29      14.09       0.9050             5.291            3.337
# 3  13.84      13.94       0.8955             5.324            3.379
# 4  16.14      14.99       0.9034             5.658            3.562
#
#    asymmetry coefficient  length of kernel groove  U/K
# 0                  2.221                    5.220    1
# 1                  1.018                    4.956    1
# 2                  2.699                    4.825    1
# 3                  2.259                    4.805    1
# 4                  1.355                    5.175    1

# %%
df1.describe()
# Out:
#              area   perimeter  compactness  length of kernel  width of kernel  \
# count  210.000000  210.000000   210.000000        210.000000       210.000000
# mean    14.847524   14.559286     0.870999          5.628533         3.258605
# std      2.909699    1.305959     0.023629          0.443063         0.377714
# min     10.590000   12.410000     0.808100          4.899000         2.630000
# 25%     12.270000   13.450000     0.856900          5.262250         2.944000
# 50%     14.355000   14.320000     0.873450          5.523500         3.237000
# 75%     17.305000   15.715000     0.887775          5.979750         3.561750
# max     21.180000   17.250000     0.918300          6.675000         4.033000
#
#        asymmetry coefficient  length of kernel groove         U/K
# count             210.000000               210.000000  210.000000
# mean                3.700201                 5.408071    2.000000
# std                 1.503557                 0.491480    0.818448
# ...

# %%
pd.set_option('display.max_rows', None) #Warning: shows ALL rows
print(df1)
# Out:
#       area  perimeter  compactness  length of kernel  width of kernel  \
# 0    15.26      14.84       0.8710             5.763            3.312
# 1    14.88      14.57       0.8811             5.554            3.333
# 2    14.29      14.09       0.9050             5.291            3.337
# 3    13.84      13.94       0.8955             5.324            3.379
# 4    16.14      14.99       0.9034             5.658            3.562
# 5    14.38      14.21       0.8951             5.386            3.312
# 6    14.69      14.49       0.8799             5.563            3.259
# 7    14.11      14.10       0.8911             5.420            3.302
# 8    16.63      15.46       0.8747             6.053            3.465
# 9    16.44      15.25       0.8880             5.884            3.505
# 10   15.26      14.85       0.8696             5.714            3.242
# 11   14.03      14.16       0.8796             5.438            3.201
# ...

# %%
round(df1.describe())
# Out:
#         area  perimeter  compactness  length of kernel  width of kernel  \
# count  210.0      210.0        210.0             210.0            210.0
# mean    15.0       15.0          1.0               6.0              3.0
# std      3.0        1.0          0.0               0.0              0.0
# min     11.0       12.0          1.0               5.0              3.0
# 25%     12.0       13.0          1.0               5.0              3.0
# 50%     14.0       14.0          1.0               6.0              3.0
# 75%     17.0       16.0          1.0               6.0              4.0
# max     21.0       17.0          1.0               7.0              4.0
#
#        asymmetry coefficient  length of kernel groove    U/K
# count                  210.0                    210.0  210.0
# mean                     4.0                      5.0    2.0
# std                      2.0                      0.0    1.0
# min                      1.0                      5.0    1.0
# ...

# %%
sns.pairplot(df1)
plt.show()

# %%
dfPlot = df1[["area", "perimeter", "compactness", "length of kernel", "width of kernel", "asymmetry coefficient", "length of kernel groove", "U/K"]]
sns.pairplot(dfPlot, corner=True)
plt.show()
